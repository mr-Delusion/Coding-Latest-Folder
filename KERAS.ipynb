# %% [markdown]
# <a href="https://colab.research.google.com/github/mr-Delusion/Coding-Latest-Folder/blob/main/KERAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

# %%
from google.colab import files
file = files.upload()
# Out:
#      <input type="file" id="files-c014706f-f9e3-4387-b165-096046d0b08d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c014706f-f9e3-4387-b165-096046d0b08d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("housing_data.csv")
df.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
y = df.pop("AboveMedianPrice")
x = df

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(10, kernel_initializer="normal", activation="relu"))
model.add(Dense(6, kernel_initializer="normal", activation="relu"))
model.add(Dense(1, kernel_initializer="normal"))

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
#fitting and training
model_history = model.fit(X_train, y_train, batch_size=10, epochs=100)
model.summary()
# Out:
# Epoch 1/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.2376
# Epoch 2/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1901
# Epoch 3/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1922
# Epoch 4/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1842
# Epoch 5/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1842
# Epoch 6/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1964
# Epoch 7/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012
# Epoch 8/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1759
# Epoch 9/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1870
# Epoch 10/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1750
# Epoch 11/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1789
# Epoch 12/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1748
# Epoch 13/100
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1711
# Epoch 14/100
# ...

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# array([[ 0.8713448 ],
#        [ 0.21955737],
#        [ 0.2718666 ],
#        [ 0.60381985],
#        [ 0.13396299],
#        [ 0.24827674],
#        [ 0.87207735],
#        [ 0.47297344],
#        [ 1.275788  ],
#        [ 0.30102488],
#        [ 0.55014455],
#        [ 0.67617786],
#        [ 0.5608841 ],
#        [ 0.25392404],
#        [ 0.2726297 ],
#        [ 0.3297654 ],
#        [ 0.53466475],
#        [-0.02299911],
#        [ 0.32543263],
#        [ 0.21163371],
#        [ 0.5770465 ],
#        [ 0.3115444 ],
#        [ 0.40191504],
#        [ 0.3265321 ],
#        [ 0.52963865],
#        [ 0.4747629 ],
#        [ 0.34616038],
#        [-0.13773939],
#        [ 0.9544122 ],
#        [ 0.2679992 ],
#        [ 0.91973174],
#        [ 0.4268768 ],
#        [ 0.39970258],
#        [ 0.89062524],
#        [ 1.0722346 ],
#        [ 0.4401717 ],
#        [ 0.6860577 ],
#        [ 0.37272325],
#        [ 0.5946722 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, Y_pred)

# %%
mae #average error, how far oof the guesses were
# Out:
# 0.34299927949905396

# %%
1 - 0.34 #accuracy of our model
# Out:
# 0.6599999999999999
